# %% [markdown]
# ### Scipy LHS implementation crash testing

# %%
from scipy.stats.qmc import LatinHypercube as LHSampler
from matplotlib import pyplot as plt

# %%
LHS = LHSampler(d=2)
ss1 = LHS.random(100)

plt.scatter(ss1[:, 0], ss1[:, 1])
plt.show()
